# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.0-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.0-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.3 MB 6.3 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/12.3 MB 4.5 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.3 MB 4.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/12.3 MB 3.9 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.3 MB 3.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.0/12.3 MB 3.8 MB/s eta 0:00:02
#    ------------------ --------------------- 5.8/12.3 MB 3.7 MB/s eta 0:00:02
#    --------------------- ------------------ 6.6/12.3 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.3/12.3 MB 3.8 MB/s eta 0:00:02
#    --------------------------- ------------ 8.4/12.3 MB 3.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.3 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.3 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 3.7 MB/s  0:00:03
# Installing collected packages: numpy
# Successfully installed numpy-2.4.0

# %%
import numpy as np

# %%
## create array using numpy
## create 1D array

arr1 = np.array([1,2,3,4,5])
print("1D array:", arr1)
print("Type of arr1:", type(arr1))
print("Shape of arr1:", arr1.shape)
# Out:
# 1D array: [1 2 3 4 5]
# Type of arr1: <class 'numpy.ndarray'>
# Shape of arr1: (5,)
