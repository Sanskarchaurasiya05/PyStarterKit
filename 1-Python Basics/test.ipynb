# %%
# Basic Syntax Rules  In python
## Case Sensitivity --> Python is case sensitive.

name="sanskar"
Name="chaurasiya"

print(name)  # Output: sanskar
print(Name)  # Output: chaurasiya
# Out:
# sanskar
# chaurasiya

# %% [markdown]
# ###Indentation

# %%
## Indentation --> Python uses indentation to define blocks of code.
#Consistent use of space or a tab is required.

age = 20
if age>18:
    print("You are an adult.")

    print(age)
# Out:
# You are an adult.
# 20

# %%
## Line Continuation --> You can use a backslash (\) to continue a statement on the next line.

total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiple statement on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## Understanding semantics in python
# Variable assignemnt

age=32 ##kernel automatically understand age is integer

# %%
type(age)
# Out:
# int

# %%
## Type inference

variable=10
print(type(variable))
variable="sanskar"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## code example of indentation
if True:
    print("correct indentation")
    if False:
         print("this ont print")
    print("this will print")
print("outside the if block")
# Out:
# correct indentation
# this will print
# outside the if block
